# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, LeakyReLU, ELU, BatchNormalization
from keras import backend
from keras.callbacks import TensorBoard
from keras.optimizers import Adam, SGD
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# %%
data = pd.read_csv("realBetterSimulation.csv", index_col=0)

# %%
Y = data["sigma"]
X = data.drop(columns=["sigma"], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
model = Sequential()
t_l = []
v_l = []

# %%
model.add(Dense(200, input_dim=X_train.shape[1]))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dense(300))
model.add(BatchNormalization())
model.add(ELU())
model.add(Dense(300))
model.add(BatchNormalization())
model.add(ELU())
model.add(Dense(200))
model.add(BatchNormalization())
model.add(ELU())
model.add(Dense(1, activation='relu'))
model.compile(optimizer=Adam(learning_rate=0.005), loss="mae")

# %%
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_93 (Dense)            (None, 200)               1200
#
#  batch_normalization_75 (Bat  (None, 200)              800
#  chNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 200)               0
#
#  dense_94 (Dense)            (None, 300)               60300
#
#  batch_normalization_76 (Bat  (None, 300)              1200
#  chNormalization)
#
#  elu_57 (ELU)                (None, 300)               0
#
#  dense_95 (Dense)            (None, 300)               90300
#
#  batch_normalization_77 (Bat  (None, 300)              1200
#  chNormalization)
#
#  elu_58 (ELU)                (None, 300)               0
#
#  dense_96 (Dense)            (None, 200)               60200
#
#  batch_normalization_78 (Bat  (None, 200)              800
#  chNormalization)
#
#  elu_59 (ELU)                (None, 200)               0
#
#  dense_97 (Dense)            (None, 1)                 201
#
# =================================================================
# Total params: 216,201
# Trainable params: 214,201
# Non-trainable params: 2,000
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train,
                    batch_size=10240, epochs=30,
                    validation_split = 0.1,
                    callbacks=[TensorBoard()],
                    verbose=1)
# Out:
# Epoch 1/30
# /Users/macongcong/opt/anaconda3/envs/tensorflow_silicon/lib/python3.9/site-packages/keras/engine/data_adapter.py:1696: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 2023-04-16 22:35:01.355364: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 24/24 [==============================] - ETA: 0s - loss: 0.4785
# 2023-04-16 22:35:04.979355: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 24/24 [==============================] - 5s 127ms/step - loss: 0.4785 - val_loss: 0.3991
# Epoch 2/30
# 24/24 [==============================] - 2s 63ms/step - loss: 0.2425 - val_loss: 0.3723
# Epoch 3/30
# 24/24 [==============================] - 1s 61ms/step - loss: 0.2085 - val_loss: 0.4727
# Epoch 4/30
# 24/24 [==============================] - 1s 61ms/step - loss: 0.1863 - val_loss: 0.3895
# Epoch 5/30
# 24/24 [==============================] - 1s 58ms/step - loss: 0.1168 - val_loss: 0.2274
# Epoch 6/30
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0827 - val_loss: 0.2292
# Epoch 7/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0674 - val_loss: 0.1643
# Epoch 8/30
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0828 - val_loss: 0.1649
# Epoch 9/30
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0689 - val_loss: 0.1505
# Epoch 10/30
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0855 - val_loss: 0.0942
# Epoch 11/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0787 - val_loss: 0.1508
# Epoch 12/30
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0582 - val_loss: 0.1586
# Epoch 13/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0696 - val_loss: 0.1777
# Epoch 14/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0678 - val_loss: 0.3428
# Epoch 15/30
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0619 - val_loss: 0.1362
# Epoch 16/30
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0589 - val_loss: 0.1519
# Epoch 17/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0480 - val_loss: 0.1057
# Epoch 18/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0503 - val_loss: 0.0813
# Epoch 19/30
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0484 - val_loss: 0.0436
# Epoch 20/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0562 - val_loss: 0.1129
# Epoch 21/30
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0488 - val_loss: 0.1024
# Epoch 22/30
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0508 - val_loss: 0.1292
# Epoch 23/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0545 - val_loss: 0.1095
# Epoch 24/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0478 - val_loss: 0.0559
# Epoch 25/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0389 - val_loss: 0.1019
# Epoch 26/30
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0487 - val_loss: 0.0721
# Epoch 27/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0340 - val_loss: 0.0403
# Epoch 28/30
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0412 - val_loss: 0.0484
# Epoch 29/30
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0537 - val_loss: 0.1345
# Epoch 30/30
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0571 - val_loss: 0.0777

# %%
train_loss = model.history.history['loss']
val_loss = model.history.history['val_loss']
t_l.extend(train_loss) # combining two lists
v_l.extend(val_loss)
plt.plot(t_l, label='Training loss')
plt.plot(v_l, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig('volModelWithBetterData.png')
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
#   1/938 [..............................] - ETA: 2:55
# 2023-04-16 21:18:17.622316: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 938/938 [==============================] - 5s 5ms/step

# %%
pd.DataFrame(y_test)
# Out:
#            sigma
# 4941    0.874242
# 51775   0.719697
# 115253  0.496465
# 299321  0.693939
# 173570  0.367677
# ...          ...
# 199500  0.075758
# 244038  0.547980
# 79446   0.556566
# 276390  0.427778
# 144864  0.256061
#
# [30000 rows x 1 columns]

# %%
pd.DataFrame(y_pred)
# Out:
#               0
# 0      0.909092
# 1      0.667567
# 2      0.482918
# 3      0.746127
# 4      0.340762
# ...         ...
# 29995  0.010313
# 29996  0.556782
# 29997  0.547740
# 29998  0.406404
# 29999  0.258459
#
# [30000 rows x 1 columns]

# %%
mae = np.abs(y_test.values.reshape(len(y_test), 1) - y_pred)
sns.kdeplot(mae, shade=True)
plt.savefig("density.png")
# we could see huge outliers
# Out:
# /var/folders/jv/604w31hs1v964hc3p1jvb1c40000gn/T/ipykernel_38041/2728979078.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(mae, shade=True)

# %%
subData = X_test.copy()
subData["mae"] = mae

# %%
subData.describe()
# Out:
#                   S             T             r             K    call_price  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     254.891536      1.541366      0.020020    255.001973     58.465740
# std      141.639387      0.842933      0.005819    141.960330     51.090608
# min       10.000000      0.082192      0.010000      9.213894      0.001264
# 25%      131.641642      0.812374      0.015051    131.443616     18.689514
# 50%      255.245245      1.545477      0.020101    255.399301     43.083930
# 75%      377.377377      2.266897      0.025152    376.989330     84.792443
# max      500.000000      3.000000      0.030000    541.902239    273.816879
#
#                 mae
# count  3.000000e+04
# mean   3.106130e-02
# std    3.980244e-02
# min    7.182661e-08
# 25%    9.182771e-03
# 50%    1.943898e-02
# 75%    3.565710e-02
# max    4.518757e-01

# %%
subData[subData["mae"] > 0.1].describe()
# Out:
#                  S            T            r            K   call_price  \
# count  3237.000000  3237.000000  3237.000000  3237.000000  3237.000000
# mean    156.873642     1.498385     0.021246   156.156541    43.817243
# std     154.852913     1.019846     0.005816   154.312068    61.271174
# min      10.000000     0.082192     0.010000     9.213894     0.028808
# 25%      30.600601     0.295405     0.016465    30.604765     4.981447
# 50%      54.144144     1.589288     0.021919    54.140547    14.876765
# 75%     299.389389     2.462586     0.026364   295.997551    44.215983
# max     500.000000     3.000000     0.030000   525.182472   273.816879
#
#                mae
# count  3237.000000
# mean      0.139931
# std       0.046932
# min       0.100013
# 25%       0.108182
# 50%       0.124406
# 75%       0.151046
# max       0.514339

# %%
subData[subData["mae"] < 0.1].describe()
# Out:
#                   S             T             r             K    call_price  \
# count  26763.000000  26763.000000  26763.000000  26763.000000  26763.000000
# mean     266.746856      1.546565      0.019872    266.957384     60.237484
# std      135.226161      0.818818      0.005802    135.595993     49.426062
# min       10.000000      0.082192      0.010000      9.416600      0.001264
# 25%      149.789790      0.829898      0.014848    149.876671     21.932862
# 50%      265.545546      1.542556      0.019899    265.358467     46.516511
# 75%      384.734735      2.246452      0.024949    384.229557     86.181821
# max      500.000000      3.000000      0.030000    541.902239    271.896484
#
#                 mae
# count  26763.000000
# mean       0.043409
# std        0.027105
# min        0.000002
# 25%        0.020696
# 50%        0.040532
# 75%        0.064574
# max        0.099986

# %%
model.save('vol_model.h5')
